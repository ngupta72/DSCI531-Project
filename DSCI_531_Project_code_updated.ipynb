# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read the data

# %%
parent_income_percentile = pd.read_excel("Dataset/Statistics_By_Parent_or_child_Income_Percentile.xlsx", sheet_name = 1)
child_income_percentile = pd.read_excel("Dataset/Statistics_By_Parent_or_child_Income_Percentile.xlsx", sheet_name = 2)

# %%
child_income_percentile.head()
# Out:
#    kid_fam_bin   bin_n  par_fam_inc  par_inc_log  kid_fam_inc  kid_inc_log  \
# 0            1   33382       205400      11.2734       -43800          NaN
# 1            4  602567        56600      10.3836            0          NaN
# 2            7   54799        61500      10.4466          100       4.0883
# 3            8   98668        60500      10.4699          500       6.1620
# 4            9   98678        64700      10.5131         1300       7.1669
#
#    kid_inc_log_z  kid_inc_log_z1000  college
# 0         0.0000            0.00000  0.75774
# 1         0.0000            0.00000  0.26596
# 2         4.0959            0.00000  0.29380
# 3         6.1620            0.00050  0.30406
# 4         7.1669            0.27825  0.32993

# %% [markdown]
# ### Plotting the Income vs College Attendence

# %%
fig, ax = plt.subplots()
sns.lineplot(data = parent_income_percentile, x = "par_bin", y = "college", ax = ax)
ax.set_xlabel("Income Percentile of parent family")
ax.set_ylabel("Sharing of children attending college")
ax.set_title("Figure 1")
plt.show()

# %% [markdown]
# ### For slides

# %%
fig, axs = plt.subplots(1, 2,figsize=(12, 8))
fig.tight_layout() 
##Fig 0
sns.lineplot(data = parent_income_percentile, x = "par_bin", y = "college", ax = axs[0])
axs[0].set_xlabel("Income Percentile of parent family")
axs[0].set_ylabel("Sharing of children attending college")
#ax.set_title("Income Percentile of Family and Share of Children attending College")
## Fig1
sns.lineplot(data = parent_income_percentile, x = "par_bin", y = "par_fam_inc", ax = axs[1])
axs[1].set_xlabel("Income Percentile of parent family")
axs[1].set_ylabel("Parental Family Income")
plt.show()

# %% [markdown]
# ### Income Percentile and Mean Parental Income in the group

# %%
fig, ax = plt.subplots()
sns.lineplot(data = parent_income_percentile, x = "par_bin", y = "par_fam_inc", ax = ax)
ax.set_xlabel("Income Percentile of parent family")
ax.set_ylabel("Parental Family Income")
ax.set_title("Figure 2")
plt.show()

# %% [markdown]
# ### Mean parental income of the group with Kids attending college

# %%
fig, ax = plt.subplots()
sns.lineplot(data = parent_income_percentile, x = "par_fam_inc", y = "college", ax = ax)
ax.set_xlabel("Parental Family Income")
ax.set_ylabel("Kids attending college during age 18-21")
ax.set_title("Figure 3")
plt.show()

# %% [markdown]
# > In 2019, the US median family income was estimated at $86,011 by the US Census Bureau.
#
# > we see that the 90\% mark is reached at a household income of almost $200 000

# %% [markdown]
# ### Grid Slide
# #### Comparison of family income

# %%
fig, axs = plt.subplots(1, 2,figsize=(10, 6))
fig.tight_layout() 
## Fig1
sns.lineplot(data = parent_income_percentile, x = "par_bin", y = "par_fam_inc", ax = axs[0])
axs[0].set_xlabel("Income Percentile of parent family")
axs[0].set_ylabel("Parental Family Income")

## Fig2
sns.lineplot(data = parent_income_percentile, y = "par_fam_inc", x = "college", ax = axs[1])
axs[1].set_xlabel("Kids attending college during age 18-21")
axs[1].set_ylabel("Parental Family Income")
# Out:
# Text(367.36363636363626, 0.5, 'Parental Family Income')

# %% [markdown]
# ### Parental Income and Average Kid family Income

# %%
fig, ax = plt.subplots()
sns.lineplot(data = parent_income_percentile, x = "par_fam_inc", y = "kid_fam_inc", ax = ax)
ax.set_xlabel("Parental Family Income")
ax.set_ylabel("Average kid family income")
ax.set_title("Figure 4")
plt.grid()
plt.show()

# %% [markdown]
# ### Parental Income and College Quality Rank

# %%
fig, ax = plt.subplots()
sns.lineplot(data = parent_income_percentile, x = "par_fam_inc", y = "coll_qual_20_rank", ax = ax)
ax.set_xlabel("Parental Family Income")
ax.set_ylabel("College quality rank")
ax.set_title("Figure 5")
plt.grid()
plt.show()

"""
Count of people in study with income greater than $200,000 = 493387. Only 5% of the total considered.
Only kids born into family above this income bracket has chances of attending college which were having quality rank greater than .75

Count of remaining people = 9374349
"""
# Out:
# '\nCount of people in study with income greater than $200,000 = 493387. Only 5% of the total considered.\nOnly kids born into family above this income bracket has chances of attending college which were having quality rank greater than .75\n\nCount of remaining people = 9374349\n'

# %% [markdown]
# ### Average Kid family Income and College Quality

# %%
fig, ax = plt.subplots()
sns.lineplot(data = parent_income_percentile, x = "kid_fam_inc", y = "coll_qual_20_rank", ax = ax)
ax.set_xlabel("Average kid family income")
ax.set_ylabel("College quality rank")
ax.set_title("Figure 6")
plt.grid()
plt.show()

# %% [markdown]
# ### Grids for Slide

# %%
fig, axs = plt.subplots(1, 2,figsize=(10, 6))
fig.tight_layout() 
## Fig1
sns.lineplot(data = parent_income_percentile, x = "kid_fam_inc", y = "coll_qual_20_rank", ax = axs[0])
axs[0].set_xlabel("Average kid family income")
axs[0].set_ylabel("College quality rank")

## Fig2
sns.lineplot(data = parent_income_percentile, x = "par_fam_inc", y = "coll_qual_20_rank", ax = axs[1])
axs[1].set_xlabel("Parental Family Income")
axs[1].set_ylabel("College quality rank")
plt.show()

# %% [markdown]
# ### Race and Gender

# %%
income_percentile_race_gender = pd.read_csv("Dataset/National Statistics by Parent Income Percentile, Gender, and Race.csv")

# %%
income_percentile_race_gender.head()
# Out:
#    par_pctile  count_pooled  count_aian_pooled  count_asian_pooled  \
# 0           1        213100               3300                9100
# 1           2        213100               3000                8900
# 2           3        213100               2900                8900
# 3           4        213100               2800                8900
# 4           5        213100               2900                8900
#
#    count_black_pooled  count_hisp_pooled  count_white_pooled  \
# 0               59500              34900               69000
# 1               55500              39900               69000
# 2               54000              40400               72000
# 3               53000              41900               73500
# 4               52000              42400               75000
#
#    density_aian_pooled  density_asian_pooled  density_black_pooled  ...  \
# 0                1.996                 1.328                 2.161  ...
# ...

# %%
income_percentile_race_gender.columns
# Out:
# Index(['par_pctile', 'count_pooled', 'count_aian_pooled', 'count_asian_pooled',
#        'count_black_pooled', 'count_hisp_pooled', 'count_white_pooled',
#        'density_aian_pooled', 'density_asian_pooled', 'density_black_pooled',
#        'density_hisp_pooled', 'density_white_pooled', 'kfr_aian_pooled',
#        'kfr_asian_pooled', 'kfr_black_female', 'kfr_black_male',
#        'kfr_black_pooled', 'kfr_hisp_pooled', 'kfr_nativemom_aian_pooled',
#        'kfr_nativemom_asian_pooled', 'kfr_nativemom_black_pooled',
#        'kfr_nativemom_hisp_pooled', 'kfr_nativemom_white_pooled', 'kfr_pooled',
#        'kfr_white_female', 'kfr_white_male', 'kfr_white_pooled',
#        'kid_college_black_female', 'kid_college_black_male',
#        'kid_college_white_female', 'kid_college_white_male',
#        'kid_hours_black_female', 'kid_hours_black_male',
#        'kid_hours_white_female', 'kid_hours_white_male',
#        'kid_jail_black_female', 'kid_jail_black_male', 'kid_jail_white_female',
# ...

# %% [markdown]
# ### Parent Household income rank and Percent of Children Attending College
# #### Females

# %%
fig, ax = plt.subplots()
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kid_college_black_female", ax = ax, label = "black_female")
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kid_college_white_female", ax = ax, label = "white_female")
ax.set_xlabel("Parent household income rank")
ax.set_ylabel("Percent of children with college attendance")
ax.set_title("Figure 7")
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### Parent Household income rank and Percent of Children Attending College
# #### Males

# %%
fig, ax = plt.subplots()
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kid_college_black_male", ax = ax, label = "black_male")
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kid_college_white_male", ax = ax, label = "white_male")
ax.set_xlabel("Parent household income rank")
ax.set_ylabel("Percent of children with college attendance")
ax.set_title("Figure 8")
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### Parent Household income rank and Percent of Children Attending College
# #### Race: Black

# %%
fig, ax = plt.subplots()
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kid_college_black_female", ax = ax, label = "black_female")
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kid_college_black_male", ax = ax, label = "black_male")
ax.set_xlabel("Parent household income rank")
ax.set_ylabel("Percent of children with college attendance")
ax.set_title("Figure 9")
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### Parent Household income rank and Percent of Children Attending College
# #### Race: White

# %%
fig, ax = plt.subplots()
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kid_college_white_female", ax = ax, label = "white_female")
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kid_college_white_male", ax = ax, label = "white_male")
ax.set_xlabel("Parent household income rank")
ax.set_ylabel("Percent of children with college attendance")
ax.set_title("Figure 10")
plt.legend()
plt.show()

# %% [markdown]
# ## Grid Plot
# #### Parent Household income Gender/Race Comparison

# %%
fig, axs = plt.subplots(2, 2,figsize=(13, 8))
fig.tight_layout() 
## Fig1
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kid_college_black_female", ax = axs[0,0], label = "black_female")
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kid_college_white_female", ax = axs[0,0], label = "white_female")
axs[0,0].set_xlabel("Parent household income rank")
axs[0,0].set_ylabel("Percent of children with college attendance")

## Fig2
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kid_college_black_male", ax = axs[0,1], label = "black_male")
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kid_college_white_male", ax = axs[0,1], label = "white_male")
axs[0,1].set_xlabel("Parent household income rank")
axs[0,1].set_ylabel("Percent of children with college attendance")

##Fig3
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kid_college_black_female", ax = axs[1,0], label = "black_female")
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kid_college_black_male", ax = axs[1,0], label = "black_male")
axs[1,0].set_xlabel("Parent household income rank")
axs[1,0].set_ylabel("Percent of children with college attendance")

##Fig4
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kid_college_white_female", ax = axs[1,1], label = "white_female")
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kid_college_white_male", ax = axs[1,1], label = "white_male")
axs[1,1].set_xlabel("Parent household income rank")
axs[1,1].set_ylabel("Percent of children with college attendance")

plt.subplots_adjust(left=None, bottom=.01, right=None, top=None, wspace=None, hspace=.3)

# %% [markdown]
# ### Parent Household income rank and Child with single parents
# #### Males

# %%
fig, ax = plt.subplots()
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kir_1par_black_male", ax = ax, label = "black_male")
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kir_1par_white_male", ax = ax, label = "white_male")
ax.set_xlabel("Parent household income rank")
ax.set_ylabel("Child with single parents individual income rank")
ax.set_title("Figure 11")
plt.legend()
plt.show()

# %% [markdown]
# ### Parent Household income rank and Children in cogenial families
# #### Males

# %%
fig, ax = plt.subplots()
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kir_2par_black_male", ax = ax, label = "black_male")
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kir_2par_white_male", ax = ax, label = "white_male")
ax.set_xlabel("Parent household income rank")
ax.set_ylabel("Child with two parents individual income rank")
ax.set_title("Figure 12")
plt.legend()
plt.show()

# %% [markdown]
# ## Grid Plot
# #### Parent Household income Gender/Race Comparison

# %%
fig, axs = plt.subplots(1, 2,figsize=(13, 8))
fig.tight_layout() 
## Fig1
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kir_1par_black_male", ax = axs[0], label = "black_male")
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kir_1par_white_male", ax = axs[0], label = "white_male")
axs[0].set_xlabel("Parent household income rank")
axs[0].set_ylabel("Child with single parents individual income rank")
axs[0].set_title("Single Parent Household")
## Fig2
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kir_2par_black_male", ax = axs[1], label = "black_male")
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kir_2par_white_male", ax = axs[1], label = "white_male")
axs[1].set_xlabel("Parent household income rank")
axs[1].set_ylabel("Child with two parents individual income rank")
axs[1].set_title("Conjugal family")
# Out:
# Text(0.5, 1.0, 'Conjugal family')

# %% [markdown]
# ### Kids with single parent, Cogenial and Pooled
# #### Males

# %%
plt.figure(figsize=(16, 6)) 
sns.boxplot(data=income_percentile_race_gender[["kir_white_pooled", "kir_1par_white_male", "kir_1par_black_male", "kir_black_pooled"]])
plt.title("Figure 13")
plt.show()

# %% [markdown]
# ### Children Employed at age 30 or older vs Mean Wage Rank
# #### Black Male

# %%
fig, ax = plt.subplots()
sns.lineplot(data = income_percentile_race_gender, x = "kid_pos_hours_black_male", y = "kid_wage_rank_black_male", ax = ax)
ax.set_xlabel("Percentage of children employed at age 30 or older")
ax.set_ylabel("Mean wage rank of children at age 30 or older")
ax.set_title("Figure 14")
plt.grid()
plt.show()

# %% [markdown]
# ### Children Employed at age 30 or older vs Mean Wage Rank
# #### White Male

# %%
fig, ax = plt.subplots()
sns.lineplot(data = income_percentile_race_gender, x = "kid_pos_hours_white_male", y = "kid_wage_rank_white_male", ax = ax)
ax.set_xlabel("Percentage of children employed at age 30 or older")
ax.set_ylabel("Mean wage rank of children at age 30 or older")
ax.set_title("Figure 15")
plt.grid()
plt.show()

# %% [markdown]
# > Number (percentage) of white people getting employed at the age of 30 is more compared to the black males

# %% [markdown]
# ### Percent of Children with college attendance and Mean Child family Income
# #### Black Male

# %%
fig, ax = plt.subplots()
sns.scatterplot(y="kfr_black_male", x="kid_college_black_male", data=income_percentile_race_gender, ax=ax)
ax.set_xlabel("Percent of children with college attendance")
ax.set_ylabel("Mean child family (household) income rank")
ax.set_title("Figure 16")
plt.grid()
plt.show()

# %% [markdown]
# ### Percent of Children with college attendance and Mean Child family Income
# #### Black Female

# %%
fig, ax = plt.subplots()
sns.scatterplot(y="kfr_black_female", x="kid_college_black_female", data=income_percentile_race_gender, ax=ax)
ax.set_xlabel("Percent of children with college attendance")
ax.set_ylabel("Mean child family (household) income rank")
#ax.set_title("Figure 17")
#ax.set_title("Percent of Black Females children with college attendance vs Mean child family (household) income rank")
plt.grid()
plt.show()

# %% [markdown]
# ### Percent of Children with college attendance and Mean Child family Income
# #### White Male

# %%
fig, ax = plt.subplots()
sns.scatterplot(y="kfr_white_male", x="kid_college_white_male", data=income_percentile_race_gender, ax=ax)
ax.set_xlabel("Percent of children with college attendance")
ax.set_ylabel("Mean child family (household) income rank")
ax.set_title("Figure 18")
plt.grid()
plt.show()

# %% [markdown]
# ### Percent of Children with college attendance and Mean Child family Income
# #### White Female

# %%
fig, ax = plt.subplots()
sns.scatterplot(y="kfr_white_female", x="kid_college_white_female", data=income_percentile_race_gender, ax=ax)
ax.set_xlabel("Percent of children with college attendance")
ax.set_ylabel("Mean child family (household) income rank")
ax.set_title("Figure 19")
plt.grid()
plt.show()

# %% [markdown]
# ### Grid plot Making
# ##### Comaprison of College Attendence with Child Family Income

# %%
fig, axs = plt.subplots(2, 2,figsize=(13, 8))
fig.tight_layout() 
## Fig1
sns.scatterplot(y="kfr_black_male", x="kid_college_black_male", data=income_percentile_race_gender, ax=axs[0,0])
axs[0,0].set_xlabel("Percent of children with college attendance")
axs[0,0].set_ylabel("Mean child family (household) income rank")
axs[0,0].set_title("Black Male")

## Fig2
sns.scatterplot(y="kfr_black_female", x="kid_college_black_female", data=income_percentile_race_gender, ax=axs[0,1])
axs[0,1].set_xlabel("Percent of children with college attendance")
axs[0,1].set_ylabel("Mean child family (household) income rank")
axs[0,1].set_title("Black Female")

##Fig3
sns.scatterplot(y="kfr_white_male", x="kid_college_white_male", data=income_percentile_race_gender, ax=axs[1,0])
axs[1,0].set_xlabel("Percent of children with college attendance")
axs[1,0].set_ylabel("Mean child family (household) income rank")
axs[1,0].set_title("White Male")

##Fig4
sns.scatterplot(y="kfr_white_female", x="kid_college_white_female", data=income_percentile_race_gender, ax=axs[1,1])
axs[1,1].set_xlabel("Percent of children with college attendance")
axs[1,1].set_ylabel("Mean child family (household) income rank")
axs[1,1].set_title("White Female")

plt.subplots_adjust(left=None, bottom=.01, right=None, top=None, wspace=None, hspace=.3)

# %% [markdown]
# ### College Score Card

# %%
grouped_college_score = pd.read_excel("Dataset/Clean_Grouped_CollegeScore (1).xlsx", skiprows=[0])

# %%
grouped_college_score.head()
# Out:
#                                 INSTNM        CITY  ST    ZIP    FIPS  \
# 0             Alabama A & M University      Normal  AL  35762  1089.0
# 1  University of Alabama at Birmingham  Birmingham  AL  35294  1073.0
# 2                   Amridge University  Montgomery  AL  36117  1101.0
# 3  University of Alabama in Huntsville  Huntsville  AL  35899  1089.0
# 4             Alabama State University  Montgomery  AL  36104  1101.0
#
#               COUNTY  COSTT4_A  TUITIONFEE_IN  TUITIONFEE_OUT  PCTPELL  ...  \
# 0     Madison County   22489.0         9744.0         18354.0   0.7067  ...
# 1   Jefferson County   24347.0         8568.0         19704.0   0.3632  ...
# 2  Montgomery County   17680.0         6900.0          6900.0   0.7673  ...
# 3     Madison County   23441.0        10714.0         22362.0   0.2698  ...
# 4  Montgomery County   21476.0        11068.0         19396.0   0.7448  ...
#
#    UGDS_WHITE  UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# ...

# %%
grouped_college_score.columns
# Out:
# Index(['INSTNM', 'CITY', 'ST', 'ZIP', 'FIPS', 'COUNTY', 'COSTT4_A',
#        'TUITIONFEE_IN', 'TUITIONFEE_OUT', 'PCTPELL', 'PCTFLOAN', 'FTFTPCTPELL',
#        'FTFTPCTFLOAN', 'DEBT_MDN', 'CUML_DEBT_P75', 'CUML_DEBT_P25',
#        'LO_INC_DEBT_MDN', 'WDRAW_DEBT_MDN', 'LOAN_EVER', 'CUML_DEBT_P90',
#        'CUML_DEBT_P10', 'PELL_DEBT_MDN', 'NOPELL_DEBT_MDN', 'PELL_YR6_N',
#        'NOPELL_YR6_N', 'MD_INC_DEBT_MDN', 'HI_INC_DEBT_MDN', 'OVERALL_YR6_N',
#        'COMP_ORIG_YR6_RT', 'ADM_RATE', 'ADM_RATE_ALL', 'ACTCMMID', 'SAT_AVG',
#        'UGDS', 'UGDS_WHITE', 'UGDS_BLACK', 'UGDS_HISP', 'UGDS_ASIAN',
#        'UGDS_AIAN', 'UGDS_NHPI', 'UGDS_2MOR', 'UGDS_NRA', 'UGDS_UNKN',
#        'PCT MISSING'],
#       dtype='object')

# %%
temp = grouped_college_score["ST"].value_counts()
temp = temp.to_frame()

# %%
temp.index
# Out:
# Index(['CA', 'NY', 'TX', 'FL', 'PA', 'OH', 'IL', 'MI', 'NC', 'GA', 'NJ', 'VA',
#        'MO', 'MA', 'TN', 'IN', 'PR', 'LA', 'MN', 'OK', 'AZ', 'WA', 'CO', 'SC',
#        'WI', 'KY', 'AR', 'AL', 'MD', 'IA', 'KS', 'OR', 'CT', 'WV', 'UT', 'MS',
#        'NM', 'NE', 'NV', 'NH', 'ME', 'ID', 'MT', 'ND', 'SD', 'RI', 'HI', 'VT',
#        'DE', 'DC', 'WY', 'AK', 'GU', 'VI', 'AS', 'MP', 'FM', 'PW', 'MH'],
#       dtype='object')

# %%
temp["ST"]
# Out:
# CA    623
# NY    409
# TX    400
# FL    372
# PA    335
# OH    284
# IL    240
# MI    176
# NC    173
# GA    157
# NJ    157
# VA    155
# MO    154
# MA    150
# TN    148
# IN    130
# PR    129
# LA    120
# MN    111
# OK    105
# AZ    105
# WA    104
# CO     97
# SC     97
# WI     92
# KY     89
# AR     88
# AL     86
# MD     84
# IA     81
# KS     80
# OR     76
# CT     75
# WV     72
# UT     70
# MS     58
# NM     46
# NE     45
# NV     38
# NH     37
# ME     37
# ID     36
# MT     33
# ND     28
# SD     25
# RI     23
# HI     22
# VT     21
# DE     20
# DC     18
# WY     10
# AK      9
# GU      3
# VI      2
# AS      1
# MP      1
# FM      1
# PW      1
# MH      1
# Name: ST, dtype: int64

# %%
plt.figure(figsize=(16, 20))
sns.barplot(x="ST", y=temp.index, data=temp)
plt.title("Figure 20")
plt.xlabel("States of USA")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### College cost comparison across states

# %%
plt.figure(figsize=(16, 6)) 
sns.boxplot(x="ST", y="COSTT4_A", data=grouped_college_score)
plt.title("Figure 21")
plt.xlabel("States of USA")
plt.ylabel("Average cost of attendance (academic year institutions)")
plt.show()

# %% [markdown]
# ### Statewise statistics

# %%
temp_mean = grouped_college_score.groupby(['ST']).mean()
temp_mean[["COSTT4_A", "TUITIONFEE_IN", "DEBT_MDN", "UGDS_WHITE", "UGDS_BLACK"]]
# Out:
#         COSTT4_A  TUITIONFEE_IN      DEBT_MDN  UGDS_WHITE  UGDS_BLACK
# ST
# AK  22064.285714    9286.142857   9816.000000    0.436289    0.029144
# AL  20629.338983   10325.238806  12621.188406    0.482257    0.415435
# AR  19713.700000    9331.415094   9092.974359    0.568296    0.303699
# AS   8050.000000    3950.000000           NaN    0.001000    0.000000
# AZ  21516.854167    9900.416667   9456.422680    0.428237    0.074059
# CA  28461.163043   15087.822951  11169.749540    0.254522    0.083067
# CO  25787.914894   12960.509434  10716.934066    0.547089    0.067858
# CT  31515.425000   20433.181818  11814.985507    0.481173    0.162562
# DC  43171.818182   26442.538462  13471.611111    0.264113    0.461220
# DE  28865.142857   13726.600000  10367.947368    0.466811    0.332817
# FL  26320.578947   14929.377778  10756.885522    0.331260    0.235813
# FM  10153.000000    4750.000000           NaN    0.000000    0.000000
# ...

# %% [markdown]
# ### Debt comparison of students in selected states

# %%
sns.scatterplot(y="HI_INC_DEBT_MDN", x="MD_INC_DEBT_MDN", hue="ST", data=
                grouped_college_score[grouped_college_score.ST.isin(["FL","NY","CA"])])
plt.title("Figure 22")
plt.xlabel("Median debt for students with family income between $30,001-$75,000")
plt.ylabel("Median debt for Students with family income $75,001+")
plt.show()

# %%
sns.scatterplot(y="ADM_RATE", x="UGDS_BLACK", hue="ST", data=
                grouped_college_score[grouped_college_score.ST.isin(["FL","NY","CA"])])
plt.title("Figure 23")
plt.xlabel("Enrollment of undergraduate degree-seeking students")
plt.ylabel("Admission rate")
plt.show()

# %%
sns.scatterplot(y="ADM_RATE", x="UGDS_WHITE", hue="ST", data=
                grouped_college_score[grouped_college_score.ST.isin(["FL","NY","CA"])])
plt.title("Figure 24")
plt.xlabel("Enrollment of undergraduate degree-seeking students")
plt.ylabel("Admission rate")
plt.show()

# %% [markdown]
# ### Debt analysis

# %% [markdown]
# > Performed a series of analysis to look for any hidden patterns among students with debt

# %%
sns.scatterplot(y="HI_INC_DEBT_MDN", x="MD_INC_DEBT_MDN", data=grouped_college_score[grouped_college_score.ADM_RATE <= 0.4])
plt.title("Figure 25 for Admision rate less than equal 0.4")
plt.xlabel("Median debt for students with family income between $30,001-$75,000")
plt.ylabel("Median debt for Students with family income $75,001+")
plt.show()

# %%
sns.scatterplot(y="ADM_RATE", x="MD_INC_DEBT_MDN", data=grouped_college_score)
plt.title("Figure 26")
plt.xlabel("Median debt for students with family income between $30,001-$75,000")
plt.ylabel("Admission rate")
plt.show()

# %%
sns.scatterplot(y="ADM_RATE", x="HI_INC_DEBT_MDN", data=grouped_college_score)
plt.title("Figure 27")
plt.xlabel("Median debt for Students with family income $75,001+")
plt.ylabel("Admission rate")
plt.show()

# %%
sns.scatterplot(y="HI_INC_DEBT_MDN", x="MD_INC_DEBT_MDN", data=grouped_college_score[grouped_college_score.ADM_RATE > 0.4])
plt.title("Figure 28 for Admision rate greater than 0.4")
plt.xlabel("Median debt for students with family income between $30,001-$75,000")
plt.ylabel("Median debt for Students with family income $75,001+")
plt.show()

# %%
fig, ax = plt.subplots()
sns.lineplot(data = grouped_college_score, x="ADM_RATE", y="UGDS", ax = ax)
plt.show()

# %%
sns.scatterplot(y="ADM_RATE", x="UGDS", hue="ST", data=
                grouped_college_score[grouped_college_score.ST.isin(["FL","NY","CA"])])
plt.show()

# %%
sns.scatterplot(y="ADM_RATE", x="UGDS_WHITE", hue="ST", data=
                grouped_college_score[grouped_college_score.ST.isin(["FL","NY","CA"])])
plt.show()

# %%
fig, ax = plt.subplots()
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kfr_pooled", ax = ax)
plt.show()

# %% [markdown]
# ### Simpsons paradox analysis

# %%
#plt.figure(figsize=(20, 10)) 
fig, ax = plt.subplots(figsize=(20, 10))
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kfr_pooled", ax = ax, label = "kfr_pooled")
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kfr_black_pooled", ax = ax, label = "kfr_black_pooled")
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kfr_hisp_pooled", ax = ax, label= "kfr_hisp_pooled")
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kfr_asian_pooled", ax = ax, label= "kfr_asian_pooled")
plt.show()

# %%
fig, ax = plt.subplots()
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kfr_hisp_pooled", ax = ax)
plt.show()

# %%
fig, ax = plt.subplots()
sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kfr_asian_pooled", ax = ax)
plt.show()

# %%
fig, ax = plt.subplots()
sns.lineplot(data = grouped_college_score, x="ADM_RATE", y="UGDS", ax = ax)
plt.show()

# %%
df = grouped_college_score.groupby(by=["ST"]).mean().reset_index()
df
# Out:
#     ST           ZIP          FIPS      COSTT4_A  TUITIONFEE_IN  \
# 0   AK  99644.444444   2095.444444  22064.285714    9286.142857
# 1   AL  35944.081395   1086.082353  20629.338983   10325.238806
# 2   AR  72294.318182   5105.581395  19713.700000    9331.415094
# 3   AS  96799.000000           NaN   8050.000000    3950.000000
# 4   AZ  85410.485714   4014.180952  21516.854167    9900.416667
# 5   CA  92824.009631   6055.533762  28461.163043   15087.822951
# 6   CO  80494.381443   8049.443299  25787.914894   12960.509434
# 7   CT   8669.400000   9159.383562  31515.425000   20433.181818
# 8   DC  20019.444444  11001.000000  43171.818182   26442.538462
# 9   DE  19815.950000  10002.800000  28865.142857   13726.600000
# 10  FL  33209.236559  12074.354839  26320.578947   14929.377778
# 11  FM  96941.000000           NaN  10153.000000    4750.000000
# 12  GA  30666.280255  13150.515924  24106.896907   12781.283186
# 13  GU  96916.333333  66010.000000  11989.000000    4882.000000
# ...

# %%
sns.scatterplot(y="ADM_RATE", x="UGDS", hue="ST", data=df[df.ST.isin(["FL","NY","CA"])])
# Out:
# <AxesSubplot:xlabel='UGDS', ylabel='ADM_RATE'>

# %%
fig, ax = plt.subplots()
sns.lineplot(data = df, x="LOAN_EVER", y="UGDS_WHITE", ax = ax, label = "white")
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
sns.lineplot(data = df, x="LOAN_EVER", y="UGDS_BLACK", ax = ax, label = "black")
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
sns.lineplot(data = df, x="LOAN_EVER", y="UGDS_HISP", ax = ax, label = "black")
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
sns.lineplot(data = df, x="LOAN_EVER", y="UGDS_ASIAN", ax = ax, label = "black")
# sns.lineplot(data = income_percentile_race_gender, x = "par_pctile", y = "kir_2par_white_male", ax = ax, label = "white_male")
# ax.set_xlabel("Parent household income rank")
# ax.set_ylabel("Child with two parents individual income rank")
# ax.set_title("Figure 12")
plt.legend()
plt.show()

# %%
sns.scatterplot(y="UGDS_BLACK", x="LOAN_EVER", hue="ST", data=df[df.ST.isin(["FL","NY","CA","TX","MT","NM","AZ","NV",
                                                                             "CO","CT","NJ","ND"])])
plt.show()

# %%
sns.scatterplot(y="UGDS_WHITE", x="LOAN_EVER", hue="ST", data=df[df.ST.isin(["FL","NY","CA","TX","MT","NM",
                                                                             "AZ","NV","CO","CT","NJ","ND"])])
plt.show()

# %% [markdown]
# ### Further Analysis

# %% [markdown]
# ### Income Mobility

# %%
baseline_Estimates_Absolute_Mobility = pd.read_excel("Dataset/Baseline Estimates of Absolute Mobility by Parent Income Percentile and Child Birth Cohort.xlsx")

# %% [markdown]
# #### Data preprocessing

# %%
l = list(range(1,101))
colNames = ['cohort']
colNames.extend(l)
colNames.extend(['par_frac0','cohort_mean'])

# %%
data_1940 = baseline_Estimates_Absolute_Mobility[baseline_Estimates_Absolute_Mobility.cohort == 1940]
data_1940.columns = colNames
value_1940 = data_1940.values[0][1:-2]

# %% [markdown]
# #### Year 1940

# %%
fig, ax = plt.subplots(figsize=(15, 8))
sns.lineplot(x=l, y=value_1940, ax = ax, label = "1940")
ax.set_xlabel("Parents Income percentile")
ax.set_ylabel("Percent of Children earning more than there parents")
plt.xlim([1, 101])
plt.ylim([0, 1])
# Out:
# (0.0, 1.0)

# %%
data_1950 = baseline_Estimates_Absolute_Mobility[baseline_Estimates_Absolute_Mobility.cohort == 1950]
value_1950 = data_1950.values[0][1:-2]

# %% [markdown]
# #### Year 1940 with 1950

# %%
fig, ax = plt.subplots(figsize=(15, 8))
sns.lineplot(x=l, y=value_1940, ax = ax, label = "1940")
sns.lineplot(x=l, y=value_1950, ax = ax, label = "1950")
ax.set_xlabel("Parents Income percentile")
ax.set_ylabel("Percent of Children earning more than there parents")
plt.xlim([0, 101])
plt.ylim([0, 1])
# Out:
# (0.0, 1.0)

# %%
data_1960 = baseline_Estimates_Absolute_Mobility[baseline_Estimates_Absolute_Mobility.cohort == 1960]
value_1960 = data_1960.values[0][1:-2]

# %%
fig, ax = plt.subplots(figsize=(15, 8))
sns.lineplot(x=l, y=value_1940, ax = ax, label = "1940")
sns.lineplot(x=l, y=value_1950, ax = ax, label = "1950")
sns.lineplot(x=l, y=value_1960, ax = ax, label = "1960")
ax.set_xlabel("Parents Income percentile")
ax.set_ylabel("Percent of Children earning more than there parents")
plt.xlim([0, 101])
plt.ylim([0, 1])
# Out:
# (0.0, 1.0)

# %%
data_1970 = baseline_Estimates_Absolute_Mobility[baseline_Estimates_Absolute_Mobility.cohort == 1970]
value_1970 = data_1970.values[0][1:-2]

data_1980 = baseline_Estimates_Absolute_Mobility[baseline_Estimates_Absolute_Mobility.cohort == 1980]
value_1980 = data_1980.values[0][1:-2]

# %% [markdown]
# #### All year comparison

# %%
fig, ax = plt.subplots(figsize=(15, 8))
sns.lineplot(x=l, y=value_1940, ax = ax, label = "1940")
sns.lineplot(x=l, y=value_1950, ax = ax, label = "1950")
sns.lineplot(x=l, y=value_1960, ax = ax, label = "1960")
sns.lineplot(x=l, y=value_1970, ax = ax, label = "1970")
sns.lineplot(x=l, y=value_1980, ax = ax, label = "1980")
ax.set_xlabel("Parents Income percentile")
ax.set_ylabel("Percent of Children earning more than there parents")
plt.xlim([0, 101])
plt.ylim([0, 1])
plt.savefig('income_mobility.png')
